# %%
import scalepy

target_spectra = scalepy.target_spectrum(0.6, 0.4, "ZC")

records_df_x, records_df_y = scalepy.select_records('5 6', '0 250', '0 50', 'Strike - Slip', target_spectra)

scalepy.BothComponentScaling(records_df_x, records_df_y, target_spectra)
# Out:
# C:\Users\KaratasD\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# RSN10_000 RSN10_090
# RSN16_000 RSN16_090
# RSN21_000 RSN21_090
# RSN27_000 RSN27_090
# RSN102_000 RSN102_090
# RSN314_000 RSN314_090
# RSN315_000 RSN315_090
# RSN317_000 RSN317_090
# RSN319_000 RSN319_090
# RSN499_000 RSN499_090
# RSN1748_000 RSN1748_090
# RSN10_000 RSN10_090 RSN10 9.824
# RSN16_000 RSN16_090 RSN16 4.888
# RSN21_000 RSN21_090 RSN21 8.145
# RSN27_000 RSN27_090 RSN27 3.719
# RSN102_000 RSN102_090 RSN102 4.243
# RSN314_000 RSN314_090 RSN314 2.417
# RSN315_000 RSN315_090 RSN315 3.415
# RSN317_000 RSN317_090 RSN317 1.808
# RSN319_000 RSN319_090 RSN319 0.801
# RSN499_000 RSN499_090 RSN499 3.389
# ...
