# %%
import scalepy as sp

target = sp.targetSpectrum(0.8, 0.4, 'ZA')
record_keys = sp.recordSelection('6 8', '0 250', '0 250', 'Strike - Slip', '0 15', '0 20', '0 5', target)
sp.amplitudeScaling(record_keys, target, .2 )
# Out:
# --------------------------------------------------
# magnitude_range = 6 8
# vs_range = 0 250
# rjb_range = 0 250
# fault_mechnanism = Strike - Slip
# duration_5_75_range = 0 15
# duration_5_95_range = 0 20
# arias_intensity_range = 0 5
# target_spectrum = 1
# pulse_type = Any
# period = 1
# test_run = False
# --------------------------------------------------
# Total number of PEER EQE Record is = 19880
# Total number of appropriate PEER EQE Record (1st selection) is = 32
# Total number of appropriate PEER EQE Record (2nd selection) is = 17
# --------------------------------------------------
# #1 | RSN6379-Tottori_ Japan-
# #2 | RSN6378-Tottori_ Japan-
# #3 | RSN6245-Tottori_ Japan-
# #4 | RSN172-Imperial Valley-06-
# #5 | RSN719-Superstition Hills-02-
# #6 | RSN8-Northern Calif-01-
# #7 | RSN726-Superstition Hills-02-
# #8 | RSN718-Superstition Hills-01-
# #9 | RSN175-Imperial Valley-06-
# #10 | RSN2715-Chi-Chi_ Taiwan-04-
# #11 | RSN720-Superstition Hills-02-
# --------------------------------------------------
# --------------------------------------------------
# Selected ground motions and scale factors
# RSN6379 |  "Tottori_ Japan" | 11.7006
# RSN6378 |  "Tottori_ Japan" | 8.015
# RSN6245 |  "Tottori_ Japan" | 6.3399
# RSN172 |  "Imperial Valley-06" | 1.9638
# RSN719 |  "Superstition Hills-02" | 2.4146
# RSN8 |  "Northern Calif-01" | 3.0257
# RSN726 |  "Superstition Hills-02" | 2.3397
# RSN718 |  "Superstition Hills-01" | 1.9794
# RSN175 |  "Imperial Valley-06" | 2.3096
# RSN2715 |  "Chi-Chi_ Taiwan-04" | 2.3837
# RSN720 |  "Superstition Hills-02" | 1.4373
# --------------------------------------------------
# {6379: 11.7006,
#  6378: 8.015,
#  6245: 6.3399,
#  172: 1.9638,
#  719: 2.4146,
#  8: 3.0257,
#  726: 2.3397,
#  718: 1.9794,
#  175: 2.3096,
#  2715: 2.3837,
#  720: 1.4373}
