# %%
import scalepy

target = scalepy.targetSpectrum(1.01, 0.237, 'ZC')
keys = scalepy.recordSelection('3 10', '360 760', '0 3000', 'Strike - Slip', '0 500', '0 500', '0 500', target, period=1)
scalepy.amplitudeScaling(keys, target, 1, components='rotd100')
# Out:
# --------------------------------------------------
# magnitude_range = 3 10
# vs_range = 360 760
# rjb_range = 0 3000
# fault_mechnanism = Strike - Slip
# duration_5_75_range = 0 500
# duration_5_95_range = 0 500
# arias_intensity_range = 0 500
# target_spectrum = 1
# pulse_type = Any
# period = 1
# --------------------------------------------------
# Total number of PEER EQE Record is = 19551
# Total number of appropriate PEER EQE Record (1st selection) is = 7651
# Total number of appropriate PEER EQE Record (2nd selection) is = 735
# --------------------------------------------------
# Selected ground motions and scale factors
# RSN1633 | Manjil_ Iran | 1.3953
# RSN150 | Coyote Lake | 1.5643
# RSN727 | Superstition Hills-02 | 1.3714
# RSN448 | Morgan Hill | 1.4339
# RSN901 | Big Bear-01 | 1.3802
# RSN1111 | Kobe_ Japan | 1.313
# RSN33 | Parkfield | 1.3647
# RSN240 | Mammoth Lakes-04 | 1.4144
# RSN568 | San Salvador | 1.3432
# RSN4065 | Parkfield-02_ CA | 1.3811
# ...
