# %%
import scalepy

target = scalepy.targetSpectrum(1.1, 0.25, 'ZC')
keys = scalepy.recordSelection('3 10', '360 760', '0 3000', 'Strike - Slip', '0 500', '0 500', '0 500', target, period=1)
scalepy.amplitudeScaling(keys, target, 1, components='srss')
# Out:
# --------------------------------------------------
# magnitude_range = 3 10
# vs_range = 360 760
# rjb_range = 0 3000
# fault_mechnanism = Strike - Slip
# duration_5_75_range = 0 500
# duration_5_95_range = 0 500
# arias_intensity_range = 0 500
# target_spectrum = 1
# pulse_type = Any
# period = 1
# --------------------------------------------------
# Total number of PEER EQE Record is = 19551
# Total number of appropriate PEER EQE Record (1st selection) is = 7651
# Total number of appropriate PEER EQE Record (2nd selection) is = 735
# --------------------------------------------------
# Selected ground motions and scale factors
# RSN1633 | Manjil_ Iran | 1.3024
# RSN727 | Superstition Hills-02 | 1.1746
# RSN150 | Coyote Lake | 1.2796
# RSN901 | Big Bear-01 | 1.2398
# RSN1111 | Kobe_ Japan | 1.1829
# RSN448 | Morgan Hill | 1.2244
# RSN568 | San Salvador | 1.1723
# RSN33 | Parkfield | 1.2133
# RSN569 | San Salvador | 1.209
# RSN240 | Mammoth Lakes-04 | 1.2446
# ...
