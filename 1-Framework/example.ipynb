# %%
import scalepy

record_df = scalepy.select_records('5 6', '0 250', '0 50', 'Strike - Slip')

file_list = record_df['File Name (Horizontal 1)'].to_list()

target_spectra = scalepy.target_spectrum(0.6, 0.4, "ZC")

scalepy.SingleComponentScale(file_list, target_spectra, 2)
# Out:
# {'IMPVALL-C-ELC000': 16.082, 'HOLLISTR_D-HD3255': 4.82, 'WESMORL_BRA225': 3.534, 'HOLLISTR_D-HD1255': 4.82, 'NCALIF.AG_D-FRN224': 5.366, 'HOLLISTR_A-HCH181': 4.983, 'SANJUAN_HDA270': 12.35, 'HOLLISTR_D-HD4255': 4.889, 'CABAJA_CXO090': 8.475, 'WESMORL_WLF225': 2.66, 'WESMORL_WSM090': 1.167}
